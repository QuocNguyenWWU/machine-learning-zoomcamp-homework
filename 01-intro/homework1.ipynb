# %%
import pandas as pd 
import numpy as np
# Q1. Pandas version
pd.__version__
# Out:
# '3.0.6'

# %%
df = pd.read_csv('https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv')

# %%
df.head(2)
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
#
#    acceleration  fuel_efficiency_mpg
# 0           NaN                 31.9
# 1           NaN                 31.3

# %%
# Q2. Records count
df.count
df.index
df.shape[0]
# Out:
# 10000

# %%
# Q3. Fuel types
df.fuel_type.value_counts()
df['fuel_type'].nunique()
# Out:
# 3

# %%
# Q4. Missing values
df.isnull().sum() # know each column 
df.isnull().sum().sum() # entire dataframe
(df.isnull().sum() > 0).sum() # how many column having missing numbers
# Out:
# np.int64(2)

# %%
# Q5. What's the maximum fuel efficiency of cars from Asia?
df.groupby("origin").fuel_efficiency_mpg.max().loc['Asia']
# Out:
# np.float64(41.2)

# %%
# Q6. Median value of horsepower
# Find the median value of the horsepower column in the dataset.
before = df['horsepower'].median()
# Next, calculate the most frequent value of the same horsepower column.
df['horsepower'].nunique()
frequent_value = df['horsepower'].value_counts().index[0]
frequent_value
# Use the fillna method to fill the missing values in the horsepower column with the most frequent value from the previous step.
df["horsepower"] = df["horsepower"].fillna(frequent_value)
df.isnull().sum() # check
# Now, calculate the median value of horsepower once again.
after = df['horsepower'].median()
print(before, after )
# Out:
# 254.0 252.0

# %%
#Q7. Sum of weight 
# Select all the cars from Asia
asia_df = df[
                df['origin'] == 'Asia'
            ]
# Select only columns vehicle_weight and model_year
asia_df[['vehicle_weight', 'model_year']]
# Select the first 7 values
asia_df[['vehicle_weight', 'model_year']].head(7)
# Get the underlying NumPy array. Let's call it X.
X = asia_df[['vehicle_weight', 'model_year']].head(7).values 
X
# Compute matrix-matrix multiplication between the transpose of X and X. To get the transpose, use X.T. Let's call the result XTX.
XTX = X.T.dot(X)
XTX
# Invert XTX.
XTX_inv = np.linalg.inv(XTX)
XTX_inv
# XTX_inv.dot(XTX)
# Create an array y with values [1100, 1300, 800, 900, 1000, 1100, 1200].
y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])
# Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w.
XTX_inv.dot(X.T).dot(y)
# What's the sum of all the elements of the result?
print(XTX_inv.dot(X.T).dot(y).sum())
# Out:
# 0.36919696904925486
